# %%
import pandas as pd
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt
% matplotlib inline
matplotlib.style.use('ggplot')
from datetime import timedelta
import os
import glob

def load(fname):
    with open(fname, "r") as f:
        result = pd.read_csv(f)
        result = result.convert_objects(convert_numeric=True)
    return result

# %%
df = load("./sync_100-wrkr_2/20170419_18_48_562800.csv")

df['5.Total'].plot()
plt.ylim([0, 0.02])
# Out:
# /home/ubuntu/anaconda3/envs/ray/lib/python3.5/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# (0, 0.02)

# %%
df = load("./sync_200-wrkr_6/20170419_18_06_444183.csv")
df['5.Total'].plot()
df = load("./sync_500-wrkr_6/20170419_12_34_742209.csv")
df['5.Total'].plot()
# plt.ylim([0, 0.02])
# Out:
# /home/ubuntu/anaconda3/envs/ray/lib/python3.5/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app

# %%
df = load("./sync_200-wrkr_4/20170419_17_02_760215.csv")
df['5.Total'].plot()
# Out:
# /home/ubuntu/anaconda3/envs/ray/lib/python3.5/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
