# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("../timing.csv")

# %%
wait_data = df['1.Wait'].apply(json.loads).apply(np.mean)

# %%
import matplotlib
import matplotlib.pyplot as plt
% matplotlib inline
matplotlib.style.use('ggplot')

# %%
wait_data.plot()

# %%
for key in df.keys():
    df[key] = df[key].apply(json.loads).apply(np.mean)

# %%
df[["1.Wait","Task", "Task_end", "Task_start"]].plot(subplots=True, layout=(4, 2), figsize=(20,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88d1940be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88d172f080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88d17496a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88d16c1978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88d160a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88d15df6a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88d15a8dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88d157bef0>]], dtype=object)
