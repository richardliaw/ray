# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("timing/20170418_08_20_279441.csv")

# %%
wait_data = df['1.Wait'].apply(json.loads).apply(np.mean)

# %%
import matplotlib
import matplotlib.pyplot as plt
% matplotlib inline
matplotlib.style.use('ggplot')

# %%
wait_data.plot()

# %%
for key in df.keys():
    df[key] = df[key].apply(json.loads).apply(np.mean)

# %%
df[["1.Wait","Task", "Task_end", "Task_start"]].plot(subplots=True, layout=(4, 2), figsize=(20,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f739b1920b8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f739afd1940>]], dtype=object)

# %%
df['4.Submit'].plot()

# %%
df['5.Total'].plot()

# %%
df["Current"]
# Out:
# 0     [-4.887580871582031e-05, -2.6941299438476562e-...
# 1     [-4.982948303222656e-05, -2.9087066650390625e-...
# 2     [-5.1975250244140625e-05, -7.200241088867188e-...
# 3     [-6.318092346191406e-05, -5.4836273193359375e-...
# 4     [-9.417533874511719e-05, -5.1021575927734375e-...
# 5     [-0.00018906593322753906, -5.91278076171875e-0...
# 6     [-4.9114227294921875e-05, -4.696846008300781e-...
# 7     [-5.602836608886719e-05, -4.792213439941406e-0...
# 8     [-8.702278137207031e-05, -5.1021575927734375e-...
# 9     [-5.1975250244140625e-05, -4.506111145019531e-...
# 10    [-4.38690185546875e-05, -3.409385681152344e-05...
# 11    [-5.698204040527344e-05, -5.984306335449219e-0...
# 12    [-2.6226043701171875e-05, -4.410743713378906e-...
# 13    [-5.698204040527344e-05, -4.100799560546875e-0...
# 14    [-6.103515625e-05, -3.314018249511719e-05, -4....
# 15    [-8.702278137207031e-05, -6.413459777832031e-0...
# 16    [-6.604194641113281e-05, -4.696846008300781e-0...
# ...
