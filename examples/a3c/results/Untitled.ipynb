# %%
import pandas as pd
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt
% matplotlib inline
matplotlib.style.use('ggplot')
from datetime import timedelta
import os
import glob

# %%
# Out:
# /home/ubuntu/anaconda3/envs/ray/lib/python3.5/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.

# %%
df['Current']
# Out:
# 0      6.18302159905
# 1      9.82366847992
# 2      13.2441582859
# 3      16.8372600973
# 4       20.421824441
# 5      23.9396452415
# 6      27.3954574215
# 7      30.8632606161
# 8      34.2358875954
# 9      37.9298295927
# 10     41.4322776484
# 11     45.0314408767
# 12     48.5676879275
# 13     52.2531359303
# 14     55.9448781109
# 15     59.4561200738
# 16     62.9158433962
# 17     66.5452402997
# 18     70.6604546022
# 19     74.2931072581
# 20     77.9985011494
# 21     81.5675033617
# 22     85.2956265283
# 23     89.0094402277
# 24     92.7396219313
# 25     96.3720849216
# 26     99.9957431662
# 27     103.516920214
# 28     107.468033885
# 29     111.243917428
#            ...
# 234    915.095839525
# 235    919.505283852
# 236      923.7202328
# 237    927.734086211
# 238    931.877425799
# 239    936.142834464
# 240    940.259910678
# 241    944.327818605
# 242    948.414796469
# 243    952.659241432
# 244    956.815099452
# 245    960.950579523
# ...
